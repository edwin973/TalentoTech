# %%
import math

def mostrar_menu():
  while True:
    print("Menu de Operaciónes Matematicas:")
    print("1: Sumar")
    print("2: Restar")
    print("3: Multiplicar")
    print("4: Dividir")
    print("5: Logaritmo")
    print("6: Coseno")
    print("7: Seno")
    print("8: Radian")
    print("9: Raiz Cubica")
    print("10: Raiz Cuadrada")
    print("11: Salir")

    opcion = int(input("Ingrese la operación a realizar:"))

    if opcion == 11:
      print("Gracias por usar el programa")
      break
    else:
      if opcion in [5,6,7,8,9,10]:
        num1 = float(input("Ingrese el número:"))
        num2 = 0
      else:
        num1 = float(input("Ingrese el primer número:"))
        num2 = float(input("Ingrese el segundo número:"))

    if opcion == 1:
      resultado = num1 + num2
      print("El resultado es: ",resultado)
    elif opcion == 2:
      resultado = num1 - num2
      print("El resultado es: ",resultado)
    elif opcion == 3:
      resultado = num1 * num2
      print("El resultado es: ",resultado)
    elif opcion == 4:
      if num2 == 0:
        print("No se puede realizar la operación con los datos proporcionados")
      else:
        resultado = num1 / num2
        print("El resultado es: ",resultado)
    elif opcion == 5:
      resultado = math.log(num1)
      print("El resultado es: ",resultado)
    elif opcion == 6:
      resultado = math.cos(num1)
      print("El resultado es: ",resultado)
    elif opcion == 7:
      resultado = math.sin(num1)
      print("El resultado es: ",resultado)
    elif opcion == 8:
      resultado = math.radians(num1)
      print("El resultado es: ",resultado)
    elif opcion == 9:
      resultado = math.cbrt(num1)
      print("El resultado es: ",resultado)
    elif opcion == 10:
      resultado = math.sqrt(num1)
      print("El resultado es: ",resultado)

mostrar_menu()
# Out:
# Menu de Operaciónes Matematicas:
# 1: Sumar
# 2: Restar
# 3: Multiplicar
# 4: Dividir
# 5: Logaritmo
# 6: Coseno
# 7: Seno
# 8: Radian
# 9: Raiz Cubica
# 10: Raiz Cuadrada
# 11: Salir
# Ingrese la operación a realizar:1
# Ingrese el primer número:2
# Ingrese el segundo número:2
# El resultado es:  4.0
# Menu de Operaciónes Matematicas:
# 1: Sumar
# 2: Restar
# 3: Multiplicar
# 4: Dividir
# 5: Logaritmo
# 6: Coseno
# 7: Seno
# 8: Radian
# 9: Raiz Cubica
# 10: Raiz Cuadrada
# 11: Salir
# Ingrese la operación a realizar:2
# Ingrese el primer número:3
# Ingrese el segundo número:2
# El resultado es:  1.0
# Menu de Operaciónes Matematicas:
# 1: Sumar
# 2: Restar
# 3: Multiplicar
# 4: Dividir
# 5: Logaritmo
# 6: Coseno
# 7: Seno
# 8: Radian
# 9: Raiz Cubica
# 10: Raiz Cuadrada
# 11: Salir
# Ingrese la operación a realizar:11
# Gracias por usar el programa
